# %% [markdown]
# # **Import Necessary Libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
import seaborn as sns

# %matplotlib inline
sns.set(rc={'figure.figsize': [20, 20]}, font_scale=1.4)

# %%
df=pd.read_csv('hypothyroid.csv')
df
# Out:
#      age sex on thyroxine query on thyroxine on antithyroid medication sick  \
# 0     41   F            f                  f                         f    f
# 1     23   F            f                  f                         f    f
# 2     46   M            f                  f                         f    f
# 3     70   F            t                  f                         f    f
# 4     70   F            f                  f                         f    f
# ...   ..  ..          ...                ...                       ...  ...
# 3767  30   F            f                  f                         f    f
# 3768  68   F            f                  f                         f    f
# 3769  74   F            f                  f                         f    f
# 3770  72   M            f                  f                         f    f
# 3771  64   F            f                  f                         f    f
#
#      pregnant thyroid surgery I131 treatment query hypothyroid  ...  \
# 0           f               f              f                 f  ...
# 1           f               f              f                 f  ...
# 2           f               f              f                 f  ...
# 3           f               f              f                 f  ...
# 4           f               f              f                 f  ...
# ...       ...             ...            ...               ...  ...
# 3767        f               f              f                 f  ...
# 3768        f               f              f                 f  ...
# 3769        f               f              f                 f  ...
# 3770        f               f              f                 f  ...
# 3771        f               f              f                 f  ...
#
#      TT4 measured  TT4 T4U measured   T4U FTI measured  FTI TBG measured TBG  \
# 0               t  125            t  1.14            t  109            f   ?
# 1               t  102            f     ?            f    ?            f   ?
# 2               t  109            t  0.91            t  120            f   ?
# 3               t  175            f     ?            f    ?            f   ?
# 4               t   61            t  0.87            t   70            f   ?
# ...           ...  ...          ...   ...          ...  ...          ...  ..
# 3767            f    ?            f     ?            f    ?            f   ?
# 3768            t  124            t  1.08            t  114            f   ?
# 3769            t  112            t  1.07            t  105            f   ?
# 3770            t   82            t  0.94            t   87            f   ?
# 3771            t   99            t  1.07            t   92            f   ?
#
#      referral source binaryClass
# 0               SVHC           P
# 1              other           P
# 2              other           P
# 3              other           P
# 4                SVI           P
# ...              ...         ...
# 3767           other           P
# 3768             SVI           P
# 3769           other           P
# 3770             SVI           P
# 3771           other           P
#
# [3772 rows x 30 columns]

# %% [markdown]
# ## Data Preprocessing

# %%
import pandas as pd

selected_columns = ['age', 'sex', 'pregnant', 'thyroid surgery', 'TSH', 'T3', 'TT4', 'T4U', 'binaryClass']

new_df = df.loc[:, selected_columns]
new_df
# Out:
#      age sex pregnant thyroid surgery   TSH   T3  TT4   T4U binaryClass
# 0     41   F        f               f   1.3  2.5  125  1.14           P
# 1     23   F        f               f   4.1    2  102     ?           P
# 2     46   M        f               f  0.98    ?  109  0.91           P
# 3     70   F        f               f  0.16  1.9  175     ?           P
# 4     70   F        f               f  0.72  1.2   61  0.87           P
# ...   ..  ..      ...             ...   ...  ...  ...   ...         ...
# 3767  30   F        f               f     ?    ?    ?     ?           P
# 3768  68   F        f               f     1  2.1  124  1.08           P
# 3769  74   F        f               f   5.1  1.8  112  1.07           P
# 3770  72   M        f               f   0.7    2   82  0.94           P
# 3771  64   F        f               f     1  2.2   99  1.07           P
#
# [3772 rows x 9 columns]

# %%
new_df.isnull().sum()
# Out:
# age                0
# sex                0
# pregnant           0
# thyroid surgery    0
# TSH                0
# T3                 0
# TT4                0
# T4U                0
# binaryClass        0
# dtype: int64

# %%
new_df.describe()
# Out:
#          age   sex pregnant thyroid surgery   TSH    T3   TT4   T4U  \
# count   3772  3772     3772            3772  3772  3772  3772  3772
# unique    94     3        2               2   288    70   242   147
# top       59     F        f               f     ?     ?     ?     ?
# freq      95  2480     3719            3719   369   769   231   387
#
#        binaryClass
# count         3772
# unique           2
# top              P
# freq          3481

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3772 entries, 0 to 3771
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              3772 non-null   object
#  1   sex              3772 non-null   object
#  2   pregnant         3772 non-null   object
#  3   thyroid surgery  3772 non-null   object
#  4   TSH              3772 non-null   object
#  5   T3               3772 non-null   object
#  6   TT4              3772 non-null   object
#  7   T4U              3772 non-null   object
#  8   binaryClass      3772 non-null   object
# dtypes: object(9)
# memory usage: 265.3+ KB

# %%
new_df
# Out:
#      age sex pregnant thyroid surgery   TSH   T3  TT4   T4U binaryClass
# 0     41   F        f               f   1.3  2.5  125  1.14           P
# 1     23   F        f               f   4.1    2  102     ?           P
# 2     46   M        f               f  0.98    ?  109  0.91           P
# 3     70   F        f               f  0.16  1.9  175     ?           P
# 4     70   F        f               f  0.72  1.2   61  0.87           P
# ...   ..  ..      ...             ...   ...  ...  ...   ...         ...
# 3767  30   F        f               f     ?    ?    ?     ?           P
# 3768  68   F        f               f     1  2.1  124  1.08           P
# 3769  74   F        f               f   5.1  1.8  112  1.07           P
# 3770  72   M        f               f   0.7    2   82  0.94           P
# 3771  64   F        f               f     1  2.2   99  1.07           P
#
# [3772 rows x 9 columns]

# %%
new_df["binaryClass"].value_counts()
# Out:
# P    3481
# N     291
# Name: binaryClass, dtype: int64

# %%
new_df["binaryClass"]=new_df["binaryClass"].map({"P":0,"N":1})

# %%
new_df["pregnant"].value_counts()
# Out:
# f    3719
# t      53
# Name: pregnant, dtype: int64

# %%
new_df=new_df.replace({'t':1,'f':0})

# %%
new_df
# Out:
#      age sex  pregnant  thyroid surgery   TSH   T3  TT4   T4U  binaryClass
# 0     41   F         0                0   1.3  2.5  125  1.14            0
# 1     23   F         0                0   4.1    2  102     ?            0
# 2     46   M         0                0  0.98    ?  109  0.91            0
# 3     70   F         0                0  0.16  1.9  175     ?            0
# 4     70   F         0                0  0.72  1.2   61  0.87            0
# ...   ..  ..       ...              ...   ...  ...  ...   ...          ...
# 3767  30   F         0                0     ?    ?    ?     ?            0
# 3768  68   F         0                0     1  2.1  124  1.08            0
# 3769  74   F         0                0   5.1  1.8  112  1.07            0
# 3770  72   M         0                0   0.7    2   82  0.94            0
# 3771  64   F         0                0     1  2.2   99  1.07            0
#
# [3772 rows x 9 columns]

# %%
new_df.isnull().sum()
# Out:
# age                0
# sex                0
# pregnant           0
# thyroid surgery    0
# TSH                0
# T3                 0
# TT4                0
# T4U                0
# binaryClass        0
# dtype: int64

# %%
new_df["sex"].value_counts()
# Out:
# F    2480
# M    1142
# ?     150
# Name: sex, dtype: int64

# %%
new_df['sex']=new_df['sex'].replace({"F":1,"M":0})

# %%
new_df["T3"].value_counts()
# Out:
# ?      769
# 2      238
# 1.8    207
# 2.2    201
# 1.9    189
#       ...
# 6.7      1
# 7.3      1
# 4.6      1
# 5.2      1
# 6.6      1
# Name: T3, Length: 70, dtype: int64

# %%
new_df["binaryClass"].value_counts()
# Out:
# 0    3481
# 1     291
# Name: binaryClass, dtype: int64

# %%
new_df.dtypes
# Out:
# age                object
# sex                object
# pregnant            int64
# thyroid surgery     int64
# TSH                object
# T3                 object
# TT4                object
# T4U                object
# binaryClass         int64
# dtype: object

# %%
cols = new_df.columns[new_df.dtypes.eq('object')]
new_df[cols] = new_df[cols].apply(pd.to_numeric, errors='coerce')
new_df.dtypes
# Out:
# age                float64
# sex                float64
# pregnant             int64
# thyroid surgery      int64
# TSH                float64
# T3                 float64
# TT4                float64
# T4U                float64
# binaryClass          int64
# dtype: object

# %%
new_df['sex'].fillna(new_df['sex'].mean(), inplace=True)
new_df['age'].fillna(new_df['age'].mean(), inplace=True)

# %%
from sklearn.impute import SimpleImputer

imputer = SimpleImputer(strategy='mean')

# %%
new_df['TSH'] = imputer.fit_transform(new_df[['TSH']])
new_df['T3'] = imputer.fit_transform(new_df[['T3']])
new_df['TT4'] = imputer.fit_transform(new_df[['TT4']])
new_df['T4U'] = imputer.fit_transform(new_df[['T4U']])

# %%
new_df.isnull().sum()
# Out:
# age                0
# sex                0
# pregnant           0
# thyroid surgery    0
# TSH                0
# T3                 0
# TT4                0
# T4U                0
# binaryClass        0
# dtype: int64

# %% [markdown]
# ## **Exploratory data analysis**

# %%
plt.figure(figsize=(12,6))
sns.countplot(x='binaryClass', data=new_df, palette='rocket')
# Out:
# <ipython-input-26-ef0093a196e6>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='binaryClass', data=new_df, palette='rocket')
# <Axes: xlabel='binaryClass', ylabel='count'>

# %%
plt.figure(figsize=(12,6))

sns.countplot(x='binaryClass', data=new_df, hue='sex', palette='BuPu')
# Out:
# <Axes: xlabel='binaryClass', ylabel='count'>

# %%
corr = new_df.corr()
corr
# Out:
#                       age       sex  pregnant  thyroid surgery       TSH  \
# age              1.000000  0.003606 -0.113521        -0.029502 -0.056167
# sex              0.003606  1.000000  0.079550         0.036586  0.031808
# pregnant        -0.113521  0.079550  1.000000        -0.014251 -0.019693
# thyroid surgery -0.029502  0.036586 -0.014251         1.000000  0.026230
# TSH             -0.056167  0.031808 -0.019693         0.026230  1.000000
# T3              -0.214925  0.062759  0.181147        -0.024146 -0.147331
# TT4             -0.037609  0.166989  0.172490        -0.021806 -0.261300
# T4U             -0.157523  0.225572  0.334702         0.027922  0.071028
# binaryClass     -0.003174  0.050808 -0.034516        -0.017633  0.423958
#
#                        T3       TT4       T4U  binaryClass
# age             -0.214925 -0.037609 -0.157523    -0.003174
# sex              0.062759  0.166989  0.225572     0.050808
# pregnant         0.181147  0.172490  0.334702    -0.034516
# thyroid surgery -0.024146 -0.021806  0.027922    -0.017633
# TSH             -0.147331 -0.261300  0.071028     0.423958
# T3               1.000000  0.509065  0.407242    -0.177683
# TT4              0.509065  1.000000  0.426484    -0.291677
# T4U              0.407242  0.426484  1.000000     0.028337
# binaryClass     -0.177683 -0.291677  0.028337     1.000000

# %%
plt.figure(figsize=(12,6))
sns.heatmap(corr, cmap='viridis', linecolor='k', linewidths=2, annot=True)
# Out:
# <Axes: >

# %%
x = new_df.drop('binaryClass', axis=1)
y = new_df['binaryClass']

# %%
x
# Out:
#        age  sex  pregnant  thyroid surgery       TSH      T3         TT4  \
# 0     41.0  1.0         0                0  1.300000  2.5000  125.000000
# 1     23.0  1.0         0                0  4.100000  2.0000  102.000000
# 2     46.0  0.0         0                0  0.980000  2.0135  109.000000
# 3     70.0  1.0         0                0  0.160000  1.9000  175.000000
# 4     70.0  1.0         0                0  0.720000  1.2000   61.000000
# ...    ...  ...       ...              ...       ...     ...         ...
# 3767  30.0  1.0         0                0  5.086766  2.0135  108.319345
# 3768  68.0  1.0         0                0  1.000000  2.1000  124.000000
# 3769  74.0  1.0         0                0  5.100000  1.8000  112.000000
# 3770  72.0  0.0         0                0  0.700000  2.0000   82.000000
# 3771  64.0  1.0         0                0  1.000000  2.2000   99.000000
#
#         T4U
# 0     1.140
# 1     0.995
# 2     0.910
# 3     0.995
# 4     0.870
# ...     ...
# 3767  0.995
# 3768  1.080
# 3769  1.070
# 3770  0.940
# 3771  1.070
#
# [3772 rows x 8 columns]

# %%
y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 3767    0
# 3768    0
# 3769    0
# 3770    0
# 3771    0
# Name: binaryClass, Length: 3772, dtype: int64

# %% [markdown]
# ## **training and testing data split**

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=42)

# %%
x.shape
# Out:
# (3772, 8)

# %%
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
sc.fit(x_train)
x_train = sc.transform(x_train)
x_test = sc.transform(x_test)

# %%
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.optimizers import Adam
from keras.callbacks import ReduceLROnPlateau, EarlyStopping

# %%
x.shape
# Out:
# (3772, 8)

# %%
x.shape[1]
# Out:
# 8

# %%
model = Sequential()
model.add(Dense(512,input_shape=[x.shape[1]],activation='relu'))
model.add(Dropout(0.8))
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.6))
model.add(Dense(128,activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(64,activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(1,activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 512)               4608
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 128)               32896
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 64)                8256
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense_4 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 177153 (692.00 KB)
# Trainable params: 177153 (692.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy'])

# %%
lrd = ReduceLROnPlateau(monitor = 'val_loss',
                         patience = 20,
                         verbose = 1,
                         factor = 0.75,
                         min_lr = 1e-10)

es = EarlyStopping(verbose=1, patience=20)

# %%
# %%time
history = model.fit(x=x_train, y=y_train, epochs=100, callbacks=[lrd, es], batch_size=64, validation_split=0.1)
# Out:
# Epoch 1/100
# 40/40 [==============================] - 2s 15ms/step - loss: 0.3618 - accuracy: 0.9199 - val_loss: 0.2589 - val_accuracy: 0.9187 - lr: 0.0010
# Epoch 2/100
# 40/40 [==============================] - 0s 10ms/step - loss: 0.2391 - accuracy: 0.9214 - val_loss: 0.1751 - val_accuracy: 0.9329 - lr: 0.0010
# Epoch 3/100
# 40/40 [==============================] - 0s 9ms/step - loss: 0.1931 - accuracy: 0.9375 - val_loss: 0.1446 - val_accuracy: 0.9470 - lr: 0.0010
# Epoch 4/100
# 40/40 [==============================] - 0s 9ms/step - loss: 0.1797 - accuracy: 0.9430 - val_loss: 0.1281 - val_accuracy: 0.9505 - lr: 0.0010
# Epoch 5/100
# 40/40 [==============================] - 0s 9ms/step - loss: 0.1556 - accuracy: 0.9482 - val_loss: 0.1048 - val_accuracy: 0.9576 - lr: 0.0010
# Epoch 6/100
# 40/40 [==============================] - 0s 9ms/step - loss: 0.1402 - accuracy: 0.9537 - val_loss: 0.1000 - val_accuracy: 0.9611 - lr: 0.0010
# Epoch 7/100
# 40/40 [==============================] - 0s 9ms/step - loss: 0.1343 - accuracy: 0.9517 - val_loss: 0.0786 - val_accuracy: 0.9647 - lr: 0.0010
# Epoch 8/100
# 40/40 [==============================] - 0s 10ms/step - loss: 0.1205 - accuracy: 0.9580 - val_loss: 0.0741 - val_accuracy: 0.9717 - lr: 0.0010
# Epoch 9/100
# 40/40 [==============================] - 0s 9ms/step - loss: 0.1105 - accuracy: 0.9556 - val_loss: 0.0616 - val_accuracy: 0.9823 - lr: 0.0010
# Epoch 10/100
# 40/40 [==============================] - 0s 9ms/step - loss: 0.1076 - accuracy: 0.9588 - val_loss: 0.0599 - val_accuracy: 0.9859 - lr: 0.0010
# Epoch 11/100
# 40/40 [==============================] - 0s 9ms/step - loss: 0.1099 - accuracy: 0.9619 - val_loss: 0.0575 - val_accuracy: 0.9859 - lr: 0.0010
# Epoch 12/100
# 40/40 [==============================] - 0s 9ms/step - loss: 0.1028 - accuracy: 0.9639 - val_loss: 0.0607 - val_accuracy: 0.9823 - lr: 0.0010
# Epoch 13/100
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0853 - accuracy: 0.9694 - val_loss: 0.0556 - val_accuracy: 0.9894 - lr: 0.0010
# Epoch 14/100
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0866 - accuracy: 0.9690 - val_loss: 0.0580 - val_accuracy: 0.9823 - lr: 0.0010
# Epoch 15/100
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0876 - accuracy: 0.9686 - val_loss: 0.0553 - val_accuracy: 0.9788 - lr: 0.0010
# Epoch 16/100
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0891 - accuracy: 0.9694 - val_loss: 0.0598 - val_accuracy: 0.9753 - lr: 0.0010
# Epoch 17/100
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0801 - accuracy: 0.9709 - val_loss: 0.0579 - val_accuracy: 0.9753 - lr: 0.0010
# Epoch 18/100
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0866 - accuracy: 0.9698 - val_loss: 0.0556 - val_accuracy: 0.9753 - lr: 0.0010
# Epoch 19/100
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0755 - accuracy: 0.9721 - val_loss: 0.0548 - val_accuracy: 0.9788 - lr: 0.0010
# Epoch 20/100
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0795 - accuracy: 0.9694 - val_loss: 0.0592 - val_accuracy: 0.9717 - lr: 0.0010
# Epoch 21/100
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0789 - accuracy: 0.9701 - val_loss: 0.0583 - val_accuracy: 0.9717 - lr: 0.0010
# Epoch 22/100
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0750 - accuracy: 0.9729 - val_loss: 0.0536 - val_accuracy: 0.9753 - lr: 0.0010
# Epoch 23/100
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0817 - accuracy: 0.9709 - val_loss: 0.0610 - val_accuracy: 0.9717 - lr: 0.0010
# Epoch 24/100
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0682 - accuracy: 0.9725 - val_loss: 0.0536 - val_accuracy: 0.9753 - lr: 0.0010
# Epoch 25/100
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0732 - accuracy: 0.9729 - val_loss: 0.0576 - val_accuracy: 0.9753 - lr: 0.0010
# Epoch 26/100
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0700 - accuracy: 0.9760 - val_loss: 0.0564 - val_accuracy: 0.9717 - lr: 0.0010
# Epoch 27/100
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0626 - accuracy: 0.9768 - val_loss: 0.0589 - val_accuracy: 0.9717 - lr: 0.0010
# Epoch 28/100
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0764 - accuracy: 0.9784 - val_loss: 0.0552 - val_accuracy: 0.9717 - lr: 0.0010
# Epoch 29/100
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0743 - accuracy: 0.9733 - val_loss: 0.0568 - val_accuracy: 0.9753 - lr: 0.0010
# Epoch 30/100
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0649 - accuracy: 0.9749 - val_loss: 0.0591 - val_accuracy: 0.9717 - lr: 0.0010
# Epoch 31/100
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0596 - accuracy: 0.9796 - val_loss: 0.0520 - val_accuracy: 0.9753 - lr: 0.0010
# Epoch 32/100
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0658 - accuracy: 0.9753 - val_loss: 0.0582 - val_accuracy: 0.9717 - lr: 0.0010
# Epoch 33/100
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0686 - accuracy: 0.9741 - val_loss: 0.0547 - val_accuracy: 0.9753 - lr: 0.0010
# Epoch 34/100
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0630 - accuracy: 0.9749 - val_loss: 0.0566 - val_accuracy: 0.9753 - lr: 0.0010
# Epoch 35/100
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0697 - accuracy: 0.9737 - val_loss: 0.0587 - val_accuracy: 0.9717 - lr: 0.0010
# Epoch 36/100
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0650 - accuracy: 0.9753 - val_loss: 0.0584 - val_accuracy: 0.9717 - lr: 0.0010
# Epoch 37/100
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0677 - accuracy: 0.9764 - val_loss: 0.0567 - val_accuracy: 0.9717 - lr: 0.0010
# Epoch 38/100
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0550 - accuracy: 0.9804 - val_loss: 0.0522 - val_accuracy: 0.9788 - lr: 0.0010
# Epoch 39/100
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0595 - accuracy: 0.9760 - val_loss: 0.0529 - val_accuracy: 0.9753 - lr: 0.0010
# Epoch 40/100
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0585 - accuracy: 0.9772 - val_loss: 0.0548 - val_accuracy: 0.9753 - lr: 0.0010
# Epoch 41/100
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0589 - accuracy: 0.9760 - val_loss: 0.0542 - val_accuracy: 0.9717 - lr: 0.0010
# Epoch 42/100
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0572 - accuracy: 0.9753 - val_loss: 0.0538 - val_accuracy: 0.9753 - lr: 0.0010
# Epoch 43/100
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0595 - accuracy: 0.9772 - val_loss: 0.0524 - val_accuracy: 0.9753 - lr: 0.0010
# Epoch 44/100
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0595 - accuracy: 0.9788 - val_loss: 0.0560 - val_accuracy: 0.9717 - lr: 0.0010
# Epoch 45/100
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0639 - accuracy: 0.9753 - val_loss: 0.0579 - val_accuracy: 0.9717 - lr: 0.0010
# Epoch 46/100
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0642 - accuracy: 0.9788 - val_loss: 0.0569 - val_accuracy: 0.9717 - lr: 0.0010
# Epoch 47/100
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0611 - accuracy: 0.9745 - val_loss: 0.0526 - val_accuracy: 0.9753 - lr: 0.0010
# Epoch 48/100
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0611 - accuracy: 0.9768 - val_loss: 0.0544 - val_accuracy: 0.9753 - lr: 0.0010
# Epoch 49/100
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0590 - accuracy: 0.9768 - val_loss: 0.0551 - val_accuracy: 0.9717 - lr: 0.0010
# Epoch 50/100
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0537 - accuracy: 0.9800 - val_loss: 0.0549 - val_accuracy: 0.9753 - lr: 0.0010
# Epoch 51/100
# 34/40 [========================>.....] - ETA: 0s - loss: 0.0560 - accuracy: 0.9816
# Epoch 51: ReduceLROnPlateau reducing learning rate to 0.0007500000356230885.
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0567 - accuracy: 0.9796 - val_loss: 0.0548 - val_accuracy: 0.9717 - lr: 0.0010
# Epoch 51: early stopping
# CPU times: user 26.1 s, sys: 1.17 s, total: 27.3 s
# Wall time: 21.2 s

# %% [markdown]
# ## **Prediction**

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# 30/30 [==============================] - 0s 3ms/step
# array([[5.05943490e-07],
#        [4.80301350e-01],
#        [2.61553945e-10],
#        [7.33359593e-06],
#        [4.19845214e-10],
#        [5.65729036e-14],
#        [1.50625894e-07],
#        [2.91888323e-03],
#        [5.81750037e-10],
#        [1.21335777e-08],
#        [1.59513780e-09],
#        [5.67095075e-03],
#        [2.24783658e-09],
#        [9.40931857e-01],
#        [1.84180390e-05],
#        [3.31253601e-11],
#        [2.27099827e-05],
#        [6.62489175e-09],
#        [4.19190105e-09],
#        [1.00197038e-02],
#        [3.91203002e-07],
#        [2.00478135e-05],
#        [6.58479868e-11],
#        [9.19463332e-08],
#        [3.16512997e-05],
#        [3.45204095e-12],
#        [5.66183811e-09],
#        [1.81877166e-02],
#        [6.10116363e-01],
#        [1.76247468e-05],
#        [2.93869269e-11],
#        [1.06508269e-09],
#        [8.33538932e-11],
#        [3.54598416e-03],
#        [7.80972726e-08],
#        [4.85790534e-17],
#        [2.93096694e-08],
#        [2.94631138e-03],
#        [1.16851456e-01],
#        [2.48570387e-07],
#        [1.51855051e-09],
#        [1.61819141e-02],
#        [3.05835184e-11],
#        [1.27266231e-09],
#        [4.74258677e-09],
#        [9.46880405e-08],
#        [9.33173942e-06],
#        [1.20851070e-01],
#        [6.25448592e-04],
#        [1.51417545e-08],
#        [4.02906400e-18],
#        [2.00010355e-08],
#        [9.80420078e-10],
#        [2.91888323e-03],
#        [8.27354074e-01],
#        [8.82304266e-06],
#        [9.91878210e-07],
#        [9.06044932e-07],
#        [1.07617443e-10],
#        [9.95783125e-07],
#        [9.33102190e-01],
#        [9.15862441e-01],
#        [2.64018194e-08],
#        [1.53056728e-02],
#        [3.15417403e-09],
#        [1.04989245e-04],
#        [1.33231003e-06],
#        [3.46051330e-15],
#        [1.94072647e-09],
#        [8.31203826e-04],
#        [9.07797244e-07],
#        [8.35157776e-10],
#        [4.73315431e-08],
#        [2.76363785e-08],
#        [4.02284739e-09],
#        [1.15961448e-07],
#        [4.58701415e-08],
#        [8.52541745e-01],
#        [2.61129363e-09],
#        [4.95962049e-05],
#        [1.74835861e-08],
#        [1.66280515e-07],
#        [6.79612411e-09],
#        [1.08587088e-07],
#        [4.35186913e-12],
#        [6.69280061e-13],
#        [1.15695651e-17],
#        [1.53188148e-06],
#        [8.49573910e-01],
#        [1.42059164e-09],
#        [3.95310735e-08],
#        [4.90805724e-06],
#        [1.03319035e-12],
#        [6.16660889e-11],
#        [8.89463308e-07],
#        [6.15471478e-08],
#        [2.87502666e-09],
#        [4.26594706e-05],
#        [8.49593562e-14],
#        [2.58110266e-09],
#        [5.74660897e-01],
#        [1.49769896e-09],
#        [2.67358704e-08],
#        [9.13800910e-11],
#        [8.73826678e-10],
#        [1.08941094e-05],
#        [1.88558552e-04],
#        [6.62100017e-01],
#        [1.57821873e-19],
#        [2.71832874e-07],
#        [7.09014058e-01],
#        [9.91501282e-19],
#        [7.23353599e-10],
#        [8.24918800e-08],
#        [4.15462872e-11],
#        [5.25174243e-03],
#        [5.54191999e-08],
#        [1.80953013e-11],
#        [5.98256577e-07],
#        [3.21578886e-03],
#        [4.61369641e-02],
#        [9.22928333e-01],
#        [9.11243563e-12],
#        [8.87054563e-01],
#        [3.66030184e-09],
#        [1.64247522e-05],
#        [1.27397801e-10],
#        [1.31321490e-11],
#        [5.74227750e-01],
#        [6.62188793e-12],
#        [2.29259352e-18],
#        [3.02310070e-08],
#        [7.81698227e-01],
#        [1.41977976e-08],
#        [9.00146246e-01],
#        [1.39555441e-05],
#        [3.06601407e-07],
#        [2.34401547e-08],
#        [2.74494116e-08],
#        [8.62661401e-11],
#        [7.91388954e-10],
#        [1.11820470e-12],
#        [9.58086319e-11],
#        [6.56406529e-09],
#        [1.77153754e-06],
#        [4.24782911e-07],
#        [4.45275567e-03],
#        [8.77350526e-10],
#        [3.76789657e-08],
#        [2.66756985e-07],
#        [3.05254957e-07],
#        [1.09654933e-01],
#        [1.05891922e-06],
#        [1.02388154e-09],
#        [2.40136844e-09],
#        [2.67991546e-10],
#        [1.86893456e-02],
#        [3.96037514e-08],
#        [2.03051459e-05],
#        [8.84932732e-08],
#        [2.17247925e-05],
#        [4.20708801e-09],
#        [2.23867466e-10],
#        [3.06257135e-08],
#        [8.60839725e-01],
#        [1.33064896e-04],
#        [6.76018819e-02],
#        [1.73173874e-04],
#        [9.82254148e-01],
#        [6.55870580e-10],
#        [1.03873710e-08],
#        [8.95033603e-10],
#        [5.31243613e-17],
#        [3.51934228e-03],
#        [5.10830027e-08],
#        [3.52205854e-04],
#        [1.89405768e-07],
#        [6.31124458e-11],
#        [5.56631718e-08],
#        [1.41839717e-11],
#        [2.34480249e-05],
#        [3.58665874e-03],
#        [5.25105692e-09],
#        [3.77972285e-08],
#        [5.84420140e-14],
#        [1.76454655e-08],
#        [1.56242521e-08],
#        [6.04067282e-11],
#        [7.53180132e-08],
#        [3.45267518e-03],
#        [5.24865698e-07],
#        [5.94135917e-20],
#        [2.14612417e-09],
#        [1.91346966e-15],
#        [2.62668891e-07],
#        [2.95039996e-07],
#        [1.27532616e-08],
#        [1.23938122e-07],
#        [3.00292596e-10],
#        [7.10610522e-08],
#        [2.20696457e-08],
#        [1.30862838e-06],
#        [2.83160603e-07],
#        [5.49406171e-01],
#        [1.15883260e-19],
#        [3.38863791e-03],
#        [2.31927643e-05],
#        [2.03648154e-02],
#        [5.45964245e-16],
#        [6.09595707e-13],
#        [8.52195442e-01],
#        [3.03885112e-10],
#        [4.97451698e-11],
#        [6.05168346e-12],
#        [6.54934551e-09],
#        [7.85924481e-09],
#        [3.64807155e-03],
#        [5.92010520e-06],
#        [9.67157462e-07],
#        [6.05226494e-03],
#        [4.07360901e-08],
#        [1.49614207e-05],
#        [4.12901318e-05],
#        [1.27674385e-10],
#        [4.38804371e-08],
#        [2.82559544e-03],
#        [6.41116173e-07],
#        [1.65862351e-04],
#        [1.93736504e-03],
#        [3.64199467e-03],
#        [5.75933445e-19],
#        [1.78994319e-11],
#        [3.12002740e-05],
#        [2.58361084e-08],
#        [3.36281082e-05],
#        [2.94819172e-03],
#        [7.27511829e-09],
#        [6.39375636e-11],
#        [8.91663730e-01],
#        [1.84389559e-09],
#        [8.35444602e-10],
#        [6.16101443e-06],
#        [1.27570645e-03],
#        [1.03829564e-07],
#        [3.53832199e-08],
#        [6.42614069e-08],
#        [7.16715753e-01],
#        [1.46954713e-04],
#        [2.97499425e-03],
#        [4.86204099e-09],
#        [1.05895929e-03],
#        [1.32431452e-08],
#        [3.06628700e-09],
#        [1.29369111e-08],
#        [7.03520242e-10],
#        [1.87972229e-12],
#        [1.02523218e-05],
#        [1.28556890e-08],
#        [1.10782224e-07],
#        [7.92851806e-01],
#        [1.12560211e-12],
#        [9.39731848e-09],
#        [8.18511392e-09],
#        [1.00374327e-05],
#        [2.84185280e-08],
#        [9.21050628e-07],
#        [5.86509705e-03],
#        [2.48287637e-02],
#        [1.52808055e-09],
#        [1.94477279e-09],
#        [8.60577285e-01],
#        [5.73369130e-10],
#        [1.94324695e-11],
#        [1.06007469e-09],
#        [1.27719986e-07],
#        [3.35309524e-05],
#        [2.14727480e-09],
#        [1.42763900e-11],
#        [1.30136679e-10],
#        [1.04931377e-01],
#        [2.48644300e-10],
#        [2.55829021e-02],
#        [2.71338463e-09],
#        [8.45250383e-07],
#        [1.15371153e-08],
#        [1.92241941e-07],
#        [9.14931464e-10],
#        [4.26018021e-09],
#        [5.32385691e-10],
#        [1.01441717e-12],
#        [7.12515935e-02],
#        [4.54520760e-03],
#        [1.11783998e-12],
#        [1.62022079e-05],
#        [3.89120416e-08],
#        [4.88068908e-05],
#        [5.42770628e-08],
#        [2.14819715e-06],
#        [9.71375465e-01],
#        [7.45745155e-09],
#        [8.57327632e-06],
#        [1.29180165e-07],
#        [7.90005147e-01],
#        [2.70429609e-07],
#        [4.69625970e-11],
#        [2.02100101e-10],
#        [5.24615906e-10],
#        [8.09331357e-01],
#        [1.19597144e-05],
#        [6.62231059e-07],
#        [1.34331249e-05],
#        [5.81460483e-07],
#        [3.61413416e-03],
#        [2.96751652e-02],
#        [2.45654691e-10],
#        [1.19009011e-10],
#        [4.33314256e-08],
#        [6.69555618e-07],
#        [2.82946444e-10],
#        [3.68499905e-02],
#        [5.90454405e-08],
#        [3.39269219e-03],
#        [5.28259250e-08],
#        [1.65936481e-16],
#        [4.95494645e-10],
#        [2.91821518e-08],
#        [1.80923264e-03],
#        [4.24024421e-07],
#        [4.41661552e-09],
#        [4.35577886e-06],
#        [1.37288868e-01],
#        [8.55918765e-01],
#        [1.01338173e-05],
#        [3.47954451e-17],
#        [4.18184698e-02],
#        [2.42402039e-05],
#        [2.34217732e-03],
#        [8.75275052e-09],
#        [6.68305099e-01],
#        [1.66377685e-08],
#        [1.59285605e-06],
#        [2.34593544e-03],
#        [7.08564526e-11],
#        [6.12041913e-05],
#        [1.93321366e-11],
#        [1.75218351e-09],
#        [9.28767502e-01],
#        [1.58730876e-11],
#        [2.96087048e-08],
#        [2.43097298e-09],
#        [7.61988250e-09],
#        [2.40998133e-06],
#        [5.72233461e-08],
#        [3.33985888e-08],
#        [3.43456652e-11],
#        [1.82305470e-07],
#        [6.90006300e-06],
#        [8.09329897e-02],
#        [8.46532047e-01],
#        [4.72622972e-14],
#        [5.43854013e-03],
#        [9.61152080e-04],
#        [1.79595963e-10],
#        [9.11311986e-07],
#        [1.17767200e-08],
#        [6.42631193e-08],
#        [2.12890567e-14],
#        [3.31737756e-05],
#        [2.88609881e-02],
#        [2.71096496e-08],
#        [2.98507619e-09],
#        [5.16803240e-08],
#        [7.22635118e-10],
#        [3.05957059e-07],
#        [1.65203247e-08],
#        [2.72986508e-05],
#        [3.21472599e-18],
#        [6.39781632e-08],
#        [1.16905792e-08],
#        [1.38601788e-08],
#        [1.84208821e-17],
#        [2.94006476e-03],
#        [1.85010034e-08],
#        [9.15505461e-06],
#        [4.30082359e-12],
#        [3.32423188e-02],
#        [7.78880974e-07],
#        [3.98152821e-12],
#        [1.20818419e-04],
#        [2.82600467e-06],
#        [1.11752572e-10],
#        [1.03122968e-08],
#        [2.80106124e-02],
#        [2.63816634e-17],
#        [1.20984453e-07],
#        [8.46047699e-01],
#        [1.03297975e-08],
#        [1.60778280e-10],
#        [1.96288875e-05],
#        [1.27895119e-05],
#        [4.80239351e-08],
#        [4.90849983e-09],
#        [9.68652714e-09],
#        [1.06868447e-09],
#        [4.21872492e-08],
#        [3.58808017e-03],
#        [5.68973664e-20],
#        [2.25401336e-10],
#        [9.09809172e-01],
#        [9.30440068e-01],
#        [7.54270188e-11],
#        [1.01704978e-09],
#        [3.82297891e-08],
#        [2.98659835e-08],
#        [6.27648902e-08],
#        [1.63900254e-10],
#        [5.20299472e-12],
#        [3.66367459e-07],
#        [3.19982257e-19],
#        [4.11020515e-08],
#        [4.78493689e-09],
#        [1.45116670e-15],
#        [1.41059886e-09],
#        [3.09056882e-02],
#        [1.19045908e-02],
#        [2.80922282e-18],
#        [1.45569415e-04],
#        [8.89588706e-03],
#        [7.62149952e-08],
#        [1.01921830e-06],
#        [3.84788601e-09],
#        [3.81022824e-10],
#        [7.15262445e-08],
#        [3.93155824e-05],
#        [1.11634021e-04],
#        [6.96509915e-07],
#        [4.70459236e-06],
#        [1.12201242e-07],
#        [2.26979477e-10],
#        [2.50000548e-10],
#        [6.36859321e-09],
#        [7.88669823e-08],
#        [3.44966594e-07],
#        [4.54424836e-08],
#        [5.47279114e-07],
#        [4.28262230e-14],
#        [4.72433115e-09],
#        [7.74715569e-10],
#        [8.52256894e-01],
#        [2.16422027e-08],
#        [9.45224021e-12],
#        [6.99721204e-05],
#        [9.69725255e-12],
#        [3.20020877e-03],
#        [2.32213461e-06],
#        [1.57122049e-05],
#        [1.61106128e-10],
#        [2.30252310e-11],
#        [1.36641791e-08],
#        [2.94328451e-09],
#        [1.28456361e-06],
#        [1.24604460e-08],
#        [3.01830396e-02],
#        [2.99085997e-07],
#        [9.26034093e-01],
#        [1.01807567e-14],
#        [7.60704133e-05],
#        [4.99952705e-07],
#        [9.08980429e-01],
#        [8.07544172e-01],
#        [2.48068499e-08],
#        [9.43532407e-01],
#        [5.21053513e-11],
#        [9.04010952e-01],
#        [2.95825515e-07],
#        [4.66616359e-03],
#        [1.19127591e-17],
#        [8.35054942e-12],
#        [3.09792725e-08],
#        [1.27723484e-04],
#        [2.92045204e-03],
#        [4.28052864e-08],
#        [1.38673979e-08],
#        [3.19215981e-03],
#        [6.17765505e-10],
#        [1.69805989e-10],
#        [3.87558041e-13],
#        [4.88930958e-08],
#        [1.45829063e-17],
#        [8.13956857e-01],
#        [5.12099199e-08],
#        [8.05174750e-06],
#        [6.77833676e-01],
#        [1.49592252e-05],
#        [6.36469901e-01],
#        [2.65551591e-11],
#        [6.33708896e-06],
#        [1.40268472e-12],
#        [3.30413422e-06],
#        [1.13862946e-08],
#        [3.22340179e-06],
#        [3.45267518e-03],
#        [9.04718935e-01],
#        [7.52293706e-01],
#        [9.26538885e-01],
#        [9.92900431e-01],
#        [5.81718389e-08],
#        [2.33320758e-08],
#        [7.55638704e-02],
#        [2.01590584e-08],
#        [7.89137732e-04],
#        [3.81459561e-19],
#        [5.94978715e-08],
#        [5.00443811e-03],
#        [6.41673115e-09],
#        [1.01905449e-07],
#        [7.86534449e-10],
#        [3.82025661e-07],
#        [9.75017429e-06],
#        [8.31258185e-13],
#        [1.54031511e-06],
#        [1.49717062e-06],
#        [3.02847265e-03],
#        [6.72154248e-01],
#        [2.64281407e-05],
#        [1.93160843e-09],
#        [3.14100343e-03],
#        [6.00120565e-03],
#        [3.24589270e-03],
#        [6.09805584e-01],
#        [6.95639031e-08],
#        [3.63672455e-03],
#        [5.24185125e-05],
#        [3.21578886e-03],
#        [7.57844627e-01],
#        [6.35725528e-10],
#        [3.82536797e-07],
#        [7.38930976e-06],
#        [1.81979942e-03],
#        [6.84013393e-12],
#        [5.62279411e-02],
#        [3.95623765e-08],
#        [6.63377702e-01],
#        [6.21675215e-15],
#        [8.53100955e-01],
#        [1.26714044e-08],
#        [6.21454763e-11],
#        [3.35868937e-03],
#        [2.76162638e-04],
#        [1.98277891e-01],
#        [8.17408741e-01],
#        [1.53062707e-09],
#        [2.67614322e-08],
#        [3.52919301e-07],
#        [8.70960712e-01],
#        [9.20945828e-13],
#        [9.09198541e-03],
#        [1.31031800e-06],
#        [1.07425102e-03],
#        [2.05217066e-09],
#        [2.93639751e-10],
#        [6.02672188e-08],
#        [8.70542169e-01],
#        [2.10718216e-08],
#        [3.97436270e-05],
#        [1.52510904e-06],
#        [2.26634267e-10],
#        [5.38947482e-08],
#        [1.19691479e-10],
#        [8.84231383e-07],
#        [2.15571415e-18],
#        [8.78595471e-01],
#        [7.74289077e-09],
#        [9.29401611e-10],
#        [5.57086423e-06],
#        [1.42528575e-06],
#        [1.23380076e-07],
#        [7.93218291e-08],
#        [1.11262700e-07],
#        [6.62873924e-01],
#        [2.10545227e-06],
#        [6.02175554e-09],
#        [7.72320902e-07],
#        [1.17836336e-07],
#        [2.94582942e-03],
#        [7.73290931e-10],
#        [9.85165775e-01],
#        [3.19884947e-07],
#        [8.31301510e-03],
#        [6.92303784e-11],
#        [6.17374988e-12],
#        [1.20992538e-09],
#        [2.41901694e-06],
#        [1.52753244e-13],
#        [1.89777161e-03],
#        [1.25731781e-08],
#        [3.38433033e-08],
#        [9.70054589e-06],
#        [1.16824587e-07],
#        [5.97154558e-01],
#        [1.29564611e-07],
#        [1.51271690e-02],
#        [4.26993623e-08],
#        [3.67183950e-09],
#        [2.21555325e-14],
#        [2.07203855e-11],
#        [4.51254998e-08],
#        [4.12734721e-07],
#        [5.55819835e-09],
#        [3.16496752e-02],
#        [4.46085495e-11],
#        [6.82426035e-01],
#        [9.12253217e-10],
#        [2.75649421e-04],
#        [4.70831651e-10],
#        [1.01784039e-07],
#        [4.80897933e-10],
#        [3.17789312e-03],
#        [9.41468954e-01],
#        [3.72271061e-01],
#        [2.17618549e-07],
#        [9.35822845e-01],
#        [1.21821824e-08],
#        [7.92913457e-10],
#        [5.30434530e-10],
#        [1.36388367e-09],
#        [3.95858933e-07],
#        [2.69709394e-10],
#        [6.35600742e-03],
#        [2.13632393e-05],
#        [5.31415502e-11],
#        [1.69416964e-02],
#        [4.98005470e-10],
#        [2.72164797e-08],
#        [4.94194170e-03],
#        [1.88526819e-10],
#        [2.47648527e-13],
#        [5.87245319e-09],
#        [8.06331979e-09],
#        [1.70355099e-06],
#        [1.06195557e-07],
#        [7.67933344e-03],
#        [3.43748294e-11],
#        [2.04790740e-10],
#        [2.86220683e-07],
#        [3.77026872e-08],
#        [3.45267518e-03],
#        [2.93392758e-03],
#        [4.35750735e-06],
#        [3.05669481e-08],
#        [9.21852825e-06],
#        [5.63862468e-09],
#        [4.04993949e-09],
#        [1.07865013e-07],
#        [1.63013159e-04],
#        [3.43277202e-06],
#        [4.45183057e-10],
#        [1.29894204e-07],
#        [4.41671872e-08],
#        [8.53215170e-05],
#        [9.77026511e-13],
#        [2.57650283e-17],
#        [3.70410876e-03],
#        [1.55751501e-09],
#        [5.19360960e-01],
#        [2.50030523e-14],
#        [2.47812486e-13],
#        [4.26959815e-07],
#        [4.93344754e-01],
#        [4.27319513e-08],
#        [7.51635909e-08],
#        [2.53213948e-05],
#        [4.71614960e-08],
#        [7.69097763e-09],
#        [4.05834611e-12],
#        [2.31328485e-08],
#        [1.62560134e-08],
#        [1.12854093e-06],
#        [3.11800941e-09],
#        [9.03920938e-09],
#        [1.08495369e-05],
#        [3.44652106e-12],
#        [2.56511509e-01],
#        [7.53685647e-09],
#        [5.97302519e-09],
#        [5.64500851e-07],
#        [3.69789865e-10],
#        [5.06263405e-08],
#        [3.78442433e-09],
#        [9.39133942e-01],
#        [2.44137459e-06],
#        [9.22800779e-01],
#        [1.23108839e-05],
#        [9.85887647e-01],
#        [1.62159008e-09],
#        [1.23105745e-03],
#        [1.63906111e-06],
#        [8.40934808e-06],
#        [9.87336516e-01],
#        [6.90017330e-20],
#        [4.30462575e-11],
#        [9.11512598e-03],
#        [1.55063019e-19],
#        [1.26063730e-06],
#        [3.13391996e-04],
#        [8.79200783e-08],
#        [1.32908687e-01],
#        [4.02580356e-12],
#        [9.35369428e-07],
#        [4.77876938e-06],
#        [4.16253388e-01],
#        [3.05859345e-07],
#        [4.44486083e-08],
#        [7.86512366e-09],
#        [1.92867944e-07],
#        [1.89207370e-07],
#        [1.30431954e-09],
#        [1.83739833e-19],
#        [1.08826621e-10],
#        [1.42960716e-03],
#        [1.51277817e-08],
#        [2.89374748e-06],
#        [2.43196747e-11],
#        [7.11323693e-03],
#        [9.81167674e-01],
#        [7.43625760e-01],
#        [2.94006476e-03],
#        [8.30548942e-01],
#        [3.79570876e-03],
#        [5.40111315e-12],
#        [1.08272225e-09],
#        [6.12713713e-10],
#        [3.02847265e-03],
#        [1.50270796e-06],
#        [9.64908931e-10],
#        [2.91867092e-16],
#        [1.97623404e-10],
#        [1.42732488e-05],
#        [4.06982607e-12],
#        [9.92090122e-07],
#        [2.40707095e-06],
#        [1.41850673e-04],
#        [2.79741835e-05],
#        [2.20261954e-05],
#        [9.72253457e-02],
#        [8.83263965e-06],
#        [4.19219673e-01],
#        [1.20908440e-11],
#        [2.19524707e-04],
#        [1.43086808e-07],
#        [7.59820733e-03],
#        [1.25164457e-04],
#        [5.32008248e-13],
#        [1.90899989e-08],
#        [8.57123150e-10],
#        [4.61812776e-11],
#        [9.55024421e-01],
#        [2.04639843e-08],
#        [5.58939428e-06],
#        [6.02499821e-12],
#        [1.09038269e-03],
#        [1.89518884e-01],
#        [3.04724335e-06],
#        [1.40591169e-07],
#        [1.52073917e-04],
#        [2.85251599e-06],
#        [1.30419394e-07],
#        [1.29479698e-08],
#        [1.61747327e-08],
#        [2.15466294e-04],
#        [4.96585031e-08],
#        [6.27348209e-06],
#        [3.81459309e-09],
#        [8.42146886e-09],
#        [4.30898854e-06],
#        [3.55061069e-09],
#        [4.79126350e-10],
#        [9.86646414e-01],
#        [1.31962054e-06],
#        [1.96762653e-06],
#        [6.50436482e-10],
#        [7.64639836e-08],
#        [1.32055655e-15],
#        [9.60322749e-03],
#        [6.12365847e-09],
#        [3.61827624e-05],
#        [1.03537789e-09],
#        [4.49628351e-06],
#        [1.68865135e-05],
#        [2.10987245e-08],
#        [1.96095865e-11],
#        [2.94819172e-03],
#        [3.30972229e-03],
#        [1.65511183e-02],
#        [3.79868879e-11],
#        [2.94433394e-03],
#        [3.48094140e-08],
#        [6.21366598e-06],
#        [9.87530589e-01],
#        [1.81026838e-08],
#        [1.36975782e-12],
#        [1.25793189e-08],
#        [2.23091760e-07],
#        [1.83724069e-06],
#        [1.02560037e-07],
#        [3.97315340e-12],
#        [6.84690258e-06],
#        [4.09219353e-10],
#        [2.17768594e-08],
#        [6.32491932e-12],
#        [1.69337863e-15],
#        [1.63015841e-07],
#        [1.25340121e-05],
#        [7.54191935e-01],
#        [7.25193648e-04],
#        [5.28701527e-09],
#        [2.58823070e-06],
#        [4.00913613e-09],
#        [7.31702272e-08],
#        [9.80824488e-09],
#        [7.70400010e-09],
#        [3.07527444e-05],
#        [2.93392758e-03],
#        [1.39703713e-02],
#        [3.90807819e-03],
#        [1.90545543e-04],
#        [1.39703713e-02],
#        [1.92051774e-09],
#        [2.04271790e-11],
#        [5.67163852e-07],
#        [1.09134905e-01],
#        [3.84094801e-06],
#        [2.63290278e-10],
#        [2.71629319e-02],
#        [1.47302326e-09],
#        [8.79283757e-10],
#        [6.36935157e-11],
#        [5.92064150e-02],
#        [2.14316254e-09],
#        [2.50096746e-05],
#        [1.88241129e-14],
#        [3.16277671e-09],
#        [5.96739155e-05],
#        [2.41866704e-08],
#        [6.45195032e-05],
#        [3.58114392e-02],
#        [4.90176575e-08],
#        [6.10861264e-08],
#        [1.63788445e-06],
#        [1.41379769e-06],
#        [4.27544364e-06],
#        [1.32766232e-07],
#        [1.91616277e-06],
#        [5.83471917e-02],
#        [3.17789312e-03],
#        [2.76984283e-05],
#        [2.13729628e-13],
#        [1.26526320e-05],
#        [4.83760410e-08],
#        [1.05281993e-04],
#        [8.17010086e-03],
#        [5.22498397e-07],
#        [2.45954048e-08],
#        [1.18861387e-07],
#        [7.96306312e-01],
#        [1.78446129e-08],
#        [3.88598274e-08],
#        [7.62578771e-02],
#        [1.06072595e-09],
#        [9.84635218e-09],
#        [4.36614300e-09],
#        [6.80275010e-13],
#        [1.78408271e-07],
#        [2.94819172e-03],
#        [1.65123085e-04],
#        [4.60984040e-07],
#        [7.07476092e-11],
#        [2.08294907e-07],
#        [3.24923710e-09],
#        [6.28372754e-06],
#        [2.01593657e-08],
#        [4.83800517e-03],
#        [2.16192888e-07],
#        [4.40090560e-07],
#        [2.94006476e-03],
#        [9.14499623e-08],
#        [3.16871356e-12],
#        [1.97052791e-10],
#        [2.12716873e-06],
#        [3.70185447e-08],
#        [1.13556534e-11],
#        [8.12145707e-04],
#        [1.24236278e-04],
#        [2.05701602e-11],
#        [1.60730372e-06],
#        [4.38075958e-08],
#        [8.12423050e-01],
#        [2.57865423e-07],
#        [1.47779460e-07],
#        [2.94819172e-03],
#        [7.73848966e-03],
#        [3.82632087e-03],
#        [5.77513537e-10],
#        [8.83420212e-15],
#        [2.31538611e-08],
#        [1.37245548e-10],
#        [6.20691435e-06],
#        [1.37607586e-02],
#        [1.15935150e-09],
#        [3.61885522e-11],
#        [1.85698209e-05],
#        [3.15626781e-03],
#        [8.84504789e-06],
#        [8.73280689e-03],
#        [8.09606036e-07],
#        [6.48738522e-19],
#        [9.19832543e-10],
#        [4.17436397e-09],
#        [2.41962971e-05],
#        [1.48994109e-12],
#        [7.27147210e-07],
#        [2.39298910e-01],
#        [2.99870502e-03],
#        [1.09420253e-05],
#        [5.81566974e-06],
#        [1.13808383e-07],
#        [6.09731317e-01],
#        [2.51922984e-06],
#        [6.24142427e-09],
#        [1.49887980e-12],
#        [4.71931685e-08],
#        [1.12607806e-04],
#        [3.98815470e-09],
#        [3.20760814e-11],
#        [6.78370567e-03],
#        [6.74418787e-09],
#        [5.88095190e-07],
#        [2.38477806e-08],
#        [2.00790144e-03],
#        [1.29317068e-05],
#        [1.16203340e-11],
#        [9.17826310e-06],
#        [5.28866617e-10]], dtype=float32)

# %%
y_test
# Out:
# 270     0
# 2071    1
# 3660    0
# 3207    0
# 1675    0
#        ..
# 1791    0
# 2132    0
# 162     0
# 1885    0
# 219     0
# Name: binaryClass, Length: 943, dtype: int64

# %% [markdown]
# ## Accuracy and Loss function **count**

# %%
# %%time
model.evaluate(x_test, y_test)
# Out:
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0541 - accuracy: 0.9777
# CPU times: user 179 ms, sys: 4.04 ms, total: 183 ms
# Wall time: 233 ms
# [0.054128438234329224, 0.9777306318283081]

# %% [markdown]
# ### Test Accuracy: 97.56%
# ### Loss Function: 74.17%

# %%
plt.figure(figsize=(12,6))

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')

plt.legend(['train', 'test'], loc='upper left')
plt.show()

plt.figure(figsize=(12,6))

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.show()

# %%
y_pred = model.predict(x_test)

y_pred_binary = (y_pred > 0.5).astype(int)

test_loss, test_accuracy = model.evaluate(x_test, y_test)
print(f'Test Loss: {test_loss:.4f}')
print(f'Test Accuracy: {test_accuracy * 100:.2f}%')

results_df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred_binary.flatten()})
print(results_df.head(10))

from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

conf_matrix = confusion_matrix(y_test, y_pred_binary)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Negative', 'Positive'], yticklabels=['Negative', 'Positive'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 30/30 [==============================] - 0s 5ms/step
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0541 - accuracy: 0.9777
# Test Loss: 0.0541
# Test Accuracy: 97.77%
#       Actual  Predicted
# 270        0          0
# 2071       1          0
# 3660       0          0
# 3207       0          0
# 1675       0          0
# 1200       0          0
# 2421       0          0
# 551        0          0
# 567        0          0
# 3322       0          0
